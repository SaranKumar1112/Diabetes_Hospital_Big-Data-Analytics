# %%
import pandas as pd

# Load the original data that contains the 'discharge_disposition_id' column
original_data = pd.read_csv('../data/diabetic_data.csv')

# Load your current DataFrame (if not already loaded)
data_f = pd.read_csv('../data/cleaned_diabetic_data_with_Median.csv')

# Add the 'discharge_disposition_id' column back to your current DataFrame
data_f['discharge_disposition_id'] = original_data['discharge_disposition_id']

# Save the updated DataFrame if needed
data_f.to_csv('../data/updated cleaned_diabetic_data_with_Median.csv', index=False)

# %%
import pandas as pd

#load data
data_f = pd.read_csv('../data/updated cleaned_diabetic_data_with_Median.csv')

#key variables
columns_chosen = [
    'time_in_hospital', 
    'num_lab_procedures', 
    'num_medications', 
    'number_diagnoses', 
    'discharge_disposition_id', 
    'number_outpatient',
    'age',
    'number_emergency',
    'num_procedures',
    'readmitted'
]

df_select = data_f[columns_chosen]


print(df_select.head())
